# %%
import pandas as pa
pa.set_option("display.max_rows",1000)
pa.set_option("display.max_columns",20)
pa.set_option('precision',7)
pa.set_option('large_repr', 'truncate')

# %%
import pandas as pa
data = pa.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.describe()
data.info()
data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=True)
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
# group     9 non-null object
# ounces    9 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 216.0+ bytes
#   group  ounces
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 1     a     3.0
# 0     a     4.0
# 2     a    12.0

# %%
import pandas as pd
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4, 'k2': [3, 2, 1, 3, 3, 4, 4]})
data.sort_values(by='k2')
data
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 5  two   4

# %%
data.drop_duplicates(subset='k1')
# Out:
#     k1  k2
# 0  one   3
# 3  two   3

# %%
import pandas as pd
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
def meat2animal(series):
    if series["food"]=='bacon':
        return 'pig'
    elif series["food"]=='pulled pork':
        return 'pig'
    elif series["food"]=='pastrami':
        return 'cow'
    elif series["food"]=='corned beef':
        return 'cow'
    elif series["food"]=='honey ham':
        return 'pig'
    else:
        return 'salmon'

# %%
data['animal2'] = data.apply(meat2animal,axis=1)
data
# Out:
#           food  ounces  animal animal2
# 0        bacon     4.0     pig     pig
# 1  pulled pork     3.0     pig     pig
# 2        bacon    12.0     pig     pig
# 3     Pastrami     6.0     cow  salmon
# 4  corned beef     7.5     cow     cow
# 5        Bacon     8.0     pig  salmon
# 6     pastrami     3.0     cow     cow
# 7    honey ham     5.0     pig     pig
# 8     nova lox     6.0  salmon  salmon

# %%
def is_even(n):
    if n % 2 == 0:
        print('e')
    else:
        print('o')
        
is_even(2)
# Out:
# e

# %%
import pandas as pd
data = pd.DataFrame({'fruit': ['apple', 'mango pork', 'orange', 'pineapple'],
                 'price': [4, 3, 12, 6]})
data
# Out:
#         fruit  price
# 0       apple      4
# 1  mango pork      3
# 2      orange     12
# 3   pineapple      6

# %%
df = pd.read_csv('users.dat', sep='::')
# Out:
# C:\Users\Pratik\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df
# Out:
#       UserID Gender  Age  Occupation Zipcode
# 0          1      F    1          10   48067
# 1          2      M   56          16   70072
# 2          3      M   25          15   55117
# 3          4      M   45           7   02460
# 4          5      M   25          20   55455
# 5          6      F   50           9   55117
# 6          7      M   35           1   06810
# 7          8      M   25          12   11413
# 8          9      M   25          17   61614
# 9         10      F   35           1   95370
# 10        11      F   25           1   04093
# 11        12      M   25          12   32793
# 12        13      M   45           1   93304
# 13        14      M   35           0   60126
# 14        15      M   25           7   22903
# 15        16      F   35           0   20670
# 16        17      M   50           1   95350
# 17        18      F   18           3   95825
# 18        19      M    1          10   48073
# 19        20      M   25          14   55113
# ...

# %%
import pandas as pd
datam = pd.read_table('movies.dat',sep='::', names=['movies-id','title','geners'])
# Out:
# C:\Users\Pratik\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#      movies-id                                              title  \
# 0           ﻿1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# ...

# %%
datam
# Out:
#      movies-id                                              title  \
# 0           ﻿1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
import pandas as pd
datar = pd.read_table('ratings.dat',sep='::', names=['UserID','MovieID','Rating','Timestamp'])
datar
# Out:
# C:\Users\Pratik\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#         UserID  MovieID  Rating  Timestamp
# 0           ﻿1     1193       5  978300760
# 1            1      661       3  978302109
# 2            1      914       3  978301968
# 3            1     3408       4  978300275
# 4            1     2355       5  978824291
# 5            1     1197       3  978302268
# 6            1     1287       5  978302039
# 7            1     2804       5  978300719
# 8            1      594       4  978302268
# 9            1      919       4  978301368
# 10           1      595       5  978824268
# 11           1      938       4  978301752
# 12           1     2398       4  978302281
# ...

# %%
datar.description()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-deb61fee28dd> in <module>()
# ----> 1 datar.description()
#       2
#
# C:\Users\Pratik\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'description'

# %%
datar.describe()
# Out:
#             MovieID        Rating     Timestamp
# count  1.000209e+06  1.000209e+06  1.000209e+06
# mean   1.865540e+03  3.581564e+00  9.722437e+08
# std    1.096041e+03  1.117102e+00  1.215256e+07
# min    1.000000e+00  1.000000e+00  9.567039e+08
# 25%    1.030000e+03  3.000000e+00  9.653026e+08
# 50%    1.835000e+03  4.000000e+00  9.730180e+08
# 75%    2.770000e+03  4.000000e+00  9.752209e+08
# max    3.952000e+03  5.000000e+00  1.046455e+09

# %%
df = df.merge(rsting,movies,how='inner',left_on='movieid',right_on='userid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c3319ed6e57c> in <module>()
# ----> 1 df = df.merge(rsting,movies,how='inner',left_on='movieid',right_on='userid')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

suna = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\K_meansHW_TomMitchell_data1.csv',sep=',',names=['k1','k2'])

# %%
suna
# Out:
#          k1       k2
# 0    2.2312  3.59710
# 1    1.8952  2.81760
# 2    2.0898  2.33910
# 3    0.5824  0.88725
# 4    1.9189  1.84270
# 5    0.5730  3.61330
# 6   -0.5504  2.23700
# 7    2.7569  3.54400
# 8    2.1627  0.05360
# 9    1.9479  0.97718
# 10   0.2723  0.33960
# 11   1.5659  1.83180
# 12   0.3472  3.33980
# 13   1.6865 -0.58640
# 14  -0.5057  1.03270
# 15   2.4422  2.23460
# 16   3.2436  0.76960
# 17   3.9216  0.65440
# 18   0.5464 -0.08070
# 19   1.8937  3.34560
# 20   0.5042  1.96970
# 21   0.4146  3.80540
# 22   1.5658 -0.23360
# 23  -0.0522  2.28800
# 24   0.1058  3.17680
# 25   2.6153  3.41450
# 26   0.0336  0.77330
# 27   0.3027  2.72840
# 28   0.6657 -0.07340
# 29   0.3838  2.56160
# ..      ...      ...
# 570 -1.6196 -1.54200
# 571 -3.6463 -0.98710
# 572 -1.7655 -4.01520
# 573 -0.3325 -1.37570
# 574 -2.5416 -1.22600
# 575 -3.9488 -0.43830
# 576 -2.9845 -1.75000
# 577  0.1509 -2.43160
# 578 -3.9940 -3.10960
# 579 -0.7830 -1.13150
# 580 -2.3657 -1.46300
# ...

# %%
# %matplotlib inline
plt.scatter(suna['k1'],suna['k2'])
clusters_2=KMeans(n_clusters=2)

# %%
plt.scatter(suna['k1'],suna['k2'])
clusters_2=KMeans(n_clusters=2)

# %%
clusters_2.fit(suna)
plt.scatter(suna['k1'],suna['k2'], c=clusters_2.labels.astype(np.float))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-bed4a587c8fd> in <module>()
#       1 clusters_2.fit(suna)
# ----> 2 plt.scatter(suna['k1'],suna['k2'], c=clusters_2.labels.astype(np.float))
#
# AttributeError: 'KMeans' object has no attribute 'labels'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
suna = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\K_meansHW_TomMitchell_data1.csv',sep=',',names=['k1','k2'])
suna
# Out:
#          k1       k2
# 0    2.2312  3.59710
# 1    1.8952  2.81760
# 2    2.0898  2.33910
# 3    0.5824  0.88725
# 4    1.9189  1.84270
# 5    0.5730  3.61330
# 6   -0.5504  2.23700
# 7    2.7569  3.54400
# 8    2.1627  0.05360
# 9    1.9479  0.97718
# 10   0.2723  0.33960
# 11   1.5659  1.83180
# 12   0.3472  3.33980
# 13   1.6865 -0.58640
# 14  -0.5057  1.03270
# 15   2.4422  2.23460
# 16   3.2436  0.76960
# 17   3.9216  0.65440
# 18   0.5464 -0.08070
# 19   1.8937  3.34560
# 20   0.5042  1.96970
# 21   0.4146  3.80540
# 22   1.5658 -0.23360
# 23  -0.0522  2.28800
# 24   0.1058  3.17680
# 25   2.6153  3.41450
# 26   0.0336  0.77330
# 27   0.3027  2.72840
# 28   0.6657 -0.07340
# 29   0.3838  2.56160
# ..      ...      ...
# 570 -1.6196 -1.54200
# 571 -3.6463 -0.98710
# 572 -1.7655 -4.01520
# 573 -0.3325 -1.37570
# 574 -2.5416 -1.22600
# 575 -3.9488 -0.43830
# 576 -2.9845 -1.75000
# 577  0.1509 -2.43160
# 578 -3.9940 -3.10960
# 579 -0.7830 -1.13150
# 580 -2.3657 -1.46300
# ...

# %%
# %matplotlib inline
plt.scatter(suna['k1'],suna['k2'])
clusterss=KMeans(n_clusters=3)

# %%
clusterss.fit(suna)
plt.scatter(suna['k1'],suna['k2'], c=clusterss.labels_.astype(np.float))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
sun = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\K_meansHW_TomMitchell_data2.csv',sep=',',names=['k1','k2'])
sun
# Out:
#             k1        k2
# 0   -19.179000   7.03170
# 1    -3.418900  23.61300
# 2    21.610000   3.55990
# 3   -19.661000  13.26400
# 4   -21.082000   7.11600
# 5    18.687000  14.54100
# 6    16.109000  13.29700
# 7     4.883800  21.85800
# 8   -16.549000 -11.34100
# 9     1.827700 -21.36400
# 10  -22.269000   1.14090
# 11    0.068116  22.66400
# 12   -1.398600 -22.66500
# 13   21.416000  -1.85020
# 14    8.525000  23.22300
# 15    3.138900  24.35500
# 16   15.859000  14.36000
# 17  -21.544000   2.28990
# 18   14.451000  14.28900
# 19  -13.181000  19.05900
# 20   -5.494400 -20.08800
# 21  -18.606000 -13.71200
# 22  -19.764000   7.49150
# 23   17.856000 -14.95500
# 24  -20.385000   5.61350
# 25  -15.016000 -19.00600
# 26   -1.490700  20.10500
# 27  -10.708000  20.53900
# 28   12.915000  16.70300
# 29    0.231630 -21.67700
# ..         ...       ...
# 577   0.380430   0.45802
# 578  -1.646300   1.01290
# 579   0.234450  -2.01520
# 580   1.667500   0.62429
# 581  -0.541640   0.77398
# ...

# %%
# %matplotlib inline
plt.scatter(sun['k1'],sun['k2'])
clustersss=KMeans(n_clusters=3)

# %%
clustersss.fit(sun)
plt.scatter(sun['k1'],sun['k2'], c=clustersss.labels_.astype(np.float))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
sun = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\K_meansHW_TomMitchell_data2.csv',sep=',',names=['k1','k2'])
# %matplotlib inline
plt.scatter(sun['k1'],sun['k2'])
clustersss=KMeans(n_clusters=3)
clustersss.fit(sun)
plt.scatter(sun['k1'],sun['k2'], c=clustersss.labels_.astype(np.float))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
girl = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\girls_train.csv', sep=',', names=['k1','k2'])
# %matplotlib inline
plt.scatter(girl['k1'],girl['k2'])
clustersss=KMeans(n_clusters=3)
clustersss.fit(girl)
plt.scatter(girl['k1'],girl['k2'], c=clustersss.labels_.astype(np.float))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
clg = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\ex2data1.csv', sep=',', names=['Exam1','Exam2','Accepted'])
# %matplotlib inline
plt.scatter(clg['Exam1'],clg['Exam2'],clg['Accepted'], color=['Red','Green','Blue'])
clust=KMeans(n_clusters=3)
clust.fit(clg)
#plt.scatter(clg['Exam1'],clg['Exam2'],clg['Accepted'], c=clust.labels_.astype(np.float))
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=4, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
clg = pd.read_table('\Users\Pratik\Downloads\VishwaniketanDSWorkshop2016-master\K-meansGD\ex2data1.csv', sep=',', names=['Exam1','Exam2','Accepted'])
# %matplotlib inline
plt.scatter(clg['Exam1'],clg['Exam2'],clg['Accepted'], color=['Red','Green','Blue'])
x=[clg.Exam1]
y=[clg.Exam2]
z=[clg.Accepted>0,color='red']
#clust=KMeans(n_clusters=3)
#clust.fit(clg)

# %%
mask=np.random.randn(len(clg))<0.1
train = clg[mask]
test = clg[~mask]

# %%
print train
# Out:
#         Exam1      Exam2  Accepted
# 0   34.623660  78.024693         0
# 1   30.286711  43.894998         0
# 2   35.847409  72.902198         0
# 3   60.182599  86.308552         1
# 4   79.032736  75.344376         1
# 6   61.106665  96.511426         1
# 8   76.098787  87.420570         1
# 10  95.861555  38.225278         0
# 13  69.364589  97.718692         1
# 14  39.538339  76.036811         0
# 15  53.971052  89.207350         1
# 17  67.946855  46.678574         0
# 18  70.661510  92.927138         1
# 19  76.978784  47.575964         1
# 20  67.372028  42.838438         0
# 21  89.676776  65.799366         1
# 22  50.534788  48.855812         0
# 23  34.212061  44.209529         0
# 27  93.114389  38.800670         0
# 28  61.830206  50.256108         0
# 31  85.404519  57.051984         1
# 32  52.107980  63.127624         0
# 33  52.045405  69.432860         1
# 35  54.635106  52.213886         0
# 37  64.176989  80.908061         1
# 38  74.789253  41.573415         0
# ...

# %%
print test
# Out:
#         Exam1      Exam2  Accepted
# 5   45.083277  56.316372         0
# 7   75.024746  46.554014         1
# 9   84.432820  43.533393         1
# 11  75.013658  30.603263         0
# 12  82.307053  76.481963         1
# 16  69.070144  52.740470         1
# 24  77.924091  68.972360         1
# 25  62.271014  69.954458         1
# 26  80.190181  44.821629         1
# 29  38.785804  64.995681         0
# 30  61.379289  72.807887         1
# 34  40.236894  71.167748         0
# 36  33.915500  98.869436         0
# 40  83.902394  56.308046         1
# 41  51.547720  46.856290         0
# 43  82.368754  40.618255         0
# 44  51.047752  45.822701         0
# 45  62.222676  52.060992         0
# 46  77.193035  70.458200         1
# 48  62.073064  96.768824         1
# 49  91.564975  88.696293         1
# 50  79.944818  74.163119         1
# 51  99.272527  60.999031         1
# 52  90.546714  43.390602         1
# 53  34.524514  60.396342         0
# 57  32.577200  95.598548         0
# ...

# %%
import random

with open("ex2data1.csv","rb") as f:
    data = f.read().split('\n')
